# %% [markdown]
# <a href="https://www.kaggle.com/code/princelv84/training-notebook-echolens-ultimate-image-caption?scriptVersionId=321849743" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # EchoLens: Ultimate Image Captioning Pipeline
# This notebook trains the EfficientNetB0 + Transformer Encoder-Decoder model. It features **Dynamic Path Finding** (so it never crashes on Kaggle paths), **Fixed Visualization**, and **TFLite Export** for edge-device compression.

# %% [markdown]
# ## 1. Dynamic Path Finding & Configuration

# %%
import os
import re
import pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# tf.config.run_functions_eagerly(True)
import keras
from keras import layers
from keras.applications import efficientnet
from keras.layers import TextVectorization

os.environ["KERAS_BACKEND"] = "tensorflow"
keras.utils.set_random_seed(111)

# DYNAMIC PATH FINDER
found_images_path = ""
found_captions_file = ""

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if filename.endswith(('.txt', '.csv')) and ('caption' in filename.lower() or 'result' in filename.lower()):
            found_captions_file = os.path.join(dirname, filename)
        if filename.endswith('.jpg') and not found_images_path:
            found_images_path = dirname

print(f"Dynamically Found Images Path: {found_images_path}")
print(f"Dynamically Found Captions File: {found_captions_file}")


# CONFIGURATION

config = {
    "IMAGES_PATH": found_images_path,
    "CAPTIONS_FILE": found_captions_file,
    "IMAGE_SIZE": (299, 299),
    "VOCAB_SIZE": 10000,
    "SEQ_LENGTH": 25,
    "EMBED_DIM": 512,
    "FF_DIM": 512,
    "BATCH_SIZE": 32,
    "EPOCHS": 15,
    "MODEL_PATH": "/kaggle/working/caption_model.keras",
    "VOCAB_PATH": "/kaggle/working/vectorization_layer_state.pkl"
}
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# 2026-05-24 17:01:19.270685: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779642079.509770      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779642079.578601      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779642080.113183      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779642080.113221      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779642080.113224      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779642080.113226      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Dynamically Found Images Path: /kaggle/input/datasets/princelv84/flickr30k/Images
# Dynamically Found Captions File: /kaggle/input/datasets/princelv84/flickr30k/Images/results.csv

# %% [markdown]
# ## 2. Data Loading and Preprocessing

# %%
def load_captions_data(filename):
    with open(filename, encoding="utf8") as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []
        images_to_skip = set()

        # Skip CSV Header if present
        if len(caption_data) > 0 and ("image" in caption_data[0].lower() or "caption" in caption_data[0].lower()):
            caption_data = caption_data[1:]

        for line in caption_data:
            line = line.replace('|', ',').rstrip("\n") # Handle weird delimiters just in case
            parts = line.strip().lower().split(",", 1)
            if len(parts) < 2: continue
            
            img_name, caption = parts
            img_path = os.path.join(config["IMAGES_PATH"], img_name.strip())

            tokens = caption.strip().split()
            if len(tokens) < 5 or len(tokens) > config["SEQ_LENGTH"]:
                images_to_skip.add(img_path)
                continue

            if img_path.endswith("jpg") and img_path not in images_to_skip:
                caption = "<start> " + caption.strip() + " <end>"
                text_data.append(caption)

                if img_path in caption_mapping:
                    caption_mapping[img_path].append(caption)
                else:
                    caption_mapping[img_path] = [caption]

        for img_path in images_to_skip:
            if img_path in caption_mapping:
                del caption_mapping[img_path]

        return caption_mapping, text_data

def train_val_split(caption_data, train_size=0.8, shuffle=True):
    all_images = list(caption_data.keys())
    if shuffle:
        np.random.shuffle(all_images)
    train_size = int(len(caption_data) * train_size)
    return (
        {img_name: caption_data[img_name] for img_name in all_images[:train_size]},
        {img_name: caption_data[img_name] for img_name in all_images[train_size:]}
    )

captions_mapping, text_data = load_captions_data(config["CAPTIONS_FILE"])
train_data, valid_data = train_val_split(captions_mapping)
print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(valid_data)}")
# Out:
# Training samples: 20915
# Validation samples: 5229

# %%
strip_chars = r"!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~".replace("<", "").replace(">", "")
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")

vectorization = TextVectorization(
    max_tokens=config["VOCAB_SIZE"],
    output_mode="int",
    output_sequence_length=config["SEQ_LENGTH"],
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

image_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomContrast(0.3),
])

def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, config["IMAGE_SIZE"])
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img

def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)

# def make_dataset(images, captions):
#     dataset = tf.data.Dataset.from_tensor_slices((images, captions))
#     dataset = dataset.shuffle(config["BATCH_SIZE"] * 8)
#     dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
#     dataset = dataset.batch(config["BATCH_SIZE"]).prefetch(AUTOTUNE)
#     return dataset

def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(config["BATCH_SIZE"] * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    
    # ADD THIS LINE TO CACHE IMAGES IN RAM:
    dataset = dataset.cache() 
    
    dataset = dataset.batch(config["BATCH_SIZE"]).prefetch(AUTOTUNE)
    return dataset

train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))
valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))
# Out:
# I0000 00:00:1779642261.780602      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# ## 3. Model Architecture (EfficientNet + Transformer)

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(input_shape=(*config["IMAGE_SIZE"], 3), include_top=False, weights="imagenet")
    base_model.trainable = False
    base_model_out = layers.Reshape((-1, base_model.output.shape[-1]))(base_model.output)
    return keras.models.Model(base_model.input, base_model_out)

@keras.utils.register_keras_serializable()
class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=0.0)
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)
        attention_output_1 = self.attention_1(query=inputs, value=inputs, key=inputs, training=training)
        return self.layernorm_2(inputs + attention_output_1)

@keras.utils.register_keras_serializable()
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.position_embeddings = layers.Embedding(input_dim=sequence_length, output_dim=embed_dim)
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs) * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

@keras.utils.register_keras_serializable()
class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=0.1)
        self.attention_2 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=0.1)
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.embedding = PositionalEmbedding(embed_dim=config["EMBED_DIM"], sequence_length=config["SEQ_LENGTH"], vocab_size=config["VOCAB_SIZE"])
        self.out = layers.Dense(config["VOCAB_SIZE"], activation="softmax")
        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)
        attention_output_1 = self.attention_1(query=inputs, value=inputs, key=inputs, attention_mask=combined_mask, training=training)
        out_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(query=out_1, value=encoder_outputs, key=encoder_outputs, attention_mask=padding_mask, training=training)
        out_2 = self.layernorm_2(out_1 + attention_output_2)
        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)
        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        return self.out(ffn_out)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat([tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

@keras.utils.register_keras_serializable()
class ImageCaptioningModel(keras.Model):
    def __init__(self, cnn_model, encoder, decoder, num_captions_per_image=5, image_aug=None, **kwargs):
        super().__init__(**kwargs)
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(batch_seq_inp, encoder_out, training=training, mask=mask)
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0
        if self.image_aug:
            batch_img = self.image_aug(batch_img)
        img_embed = self.cnn_model(batch_img)

        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(img_embed, batch_seq[:, i, :], training=True)
                batch_loss += loss
                batch_acc += acc
            train_vars = self.encoder.trainable_variables + self.decoder.trainable_variables
            grads = tape.gradient(loss, train_vars)
            self.optimizer.apply_gradients(zip(grads, train_vars))

        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0
        img_embed = self.cnn_model(batch_img)

        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(img_embed, batch_seq[:, i, :], training=False)
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    @property
    def metrics(self):
        return [self.loss_tracker, self.acc_tracker]

    def get_config(self):
        conf = super().get_config()
        conf.update({
            "cnn_model": keras.saving.serialize_keras_object(self.cnn_model),
            "encoder": keras.saving.serialize_keras_object(self.encoder),
            "decoder": keras.saving.serialize_keras_object(self.decoder),
            "num_captions_per_image": self.num_captions_per_image,
            "image_aug": keras.saving.serialize_keras_object(self.image_aug),
        })
        return conf

    @classmethod
    def from_config(cls, conf):
        cnn_model = keras.saving.deserialize_keras_object(conf.pop("cnn_model"))
        encoder = keras.saving.deserialize_keras_object(conf.pop("encoder"))
        decoder = keras.saving.deserialize_keras_object(conf.pop("decoder"))
        image_aug = keras.saving.deserialize_keras_object(conf.pop("image_aug"))
        num_captions_per_image = conf.pop("num_captions_per_image")
        return cls(cnn_model=cnn_model, encoder=encoder, decoder=decoder, num_captions_per_image=num_captions_per_image, image_aug=image_aug, **conf)

    def build(self, input_shape, seq_len=25):
        dummy_images = tf.zeros(input_shape)
        if self.image_aug:
            dummy_images = self.image_aug(dummy_images)
        img_embed = self.cnn_model(dummy_images)
        encoder_out = self.encoder(img_embed, training=False)
        dummy_caption = tf.zeros((input_shape[0], seq_len), dtype=tf.int32)
        dummy_mask = tf.ones_like(dummy_caption, dtype=tf.bool)
        _ = self.decoder(dummy_caption, encoder_out, training=False, mask=dummy_mask)
        super().build(input_shape)

# %% [markdown]
# ## 4. Training & Callbacks

# %%
@keras.utils.register_keras_serializable()
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(global_step < warmup_steps, lambda: warmup_learning_rate, lambda: self.post_warmup_learning_rate)

    def get_config(self):
        return {"post_warmup_learning_rate": float(self.post_warmup_learning_rate), "warmup_steps": int(self.warmup_steps)}

    @classmethod
    def from_config(cls, conf):
        return cls(**conf)

cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=config["EMBED_DIM"], dense_dim=config["FF_DIM"], num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=config["EMBED_DIM"], ff_dim=config["FF_DIM"], num_heads=2)
caption_model = ImageCaptioningModel(cnn_model=cnn_model, encoder=encoder, decoder=decoder, image_aug=image_augmentation)

cross_entropy = keras.losses.SparseCategoricalCrossentropy(from_logits=False, reduction=None)

num_train_steps = len(train_dataset) * config["EPOCHS"]
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)
caption_model.build(input_shape=(4, *config["IMAGE_SIZE"], 3))

# Callbacks to save best model and stop if it stops improving
callbacks = [
    keras.callbacks.ModelCheckpoint(config["MODEL_PATH"], save_best_only=True, save_weights_only=False, monitor="val_loss"),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)
]

print("Starting Training...")
history = caption_model.fit(
    train_dataset, 
    epochs=config["EPOCHS"], 
    validation_data=valid_dataset,
    callbacks=callbacks
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# I0000 00:00:1779642269.524074      23 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Starting Training...
# Epoch 1/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 308s 416ms/step - acc: 0.2159 - loss: 27.1994 - val_acc: 0.3554 - val_loss: 16.7906
# Epoch 2/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 393ms/step - acc: 0.3487 - loss: 16.8671 - val_acc: 0.3795 - val_loss: 15.4110
# Epoch 3/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 256s 392ms/step - acc: 0.3701 - loss: 15.5835 - val_acc: 0.3906 - val_loss: 14.8218
# Epoch 4/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 256s 392ms/step - acc: 0.3826 - loss: 14.8598 - val_acc: 0.3975 - val_loss: 14.5038
# Epoch 5/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 261s 398ms/step - acc: 0.3920 - loss: 14.3543 - val_acc: 0.4018 - val_loss: 14.2868
# Epoch 6/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 393ms/step - acc: 0.3998 - loss: 13.9700 - val_acc: 0.4049 - val_loss: 14.1939
# Epoch 7/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 393ms/step - acc: 0.4063 - loss: 13.6313 - val_acc: 0.4064 - val_loss: 14.0962
# Epoch 8/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 393ms/step - acc: 0.4122 - loss: 13.3569 - val_acc: 0.4082 - val_loss: 14.0559
# Epoch 9/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 393ms/step - acc: 0.4175 - loss: 13.1085 - val_acc: 0.4084 - val_loss: 14.0497
# Epoch 10/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 393ms/step - acc: 0.4223 - loss: 12.8912 - val_acc: 0.4088 - val_loss: 14.0490
# Epoch 11/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 255s 390ms/step - acc: 0.4269 - loss: 12.6943 - val_acc: 0.4086 - val_loss: 14.0822
# Epoch 12/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 255s 390ms/step - acc: 0.4314 - loss: 12.5047 - val_acc: 0.4091 - val_loss: 14.0896
# Epoch 13/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 255s 391ms/step - acc: 0.4351 - loss: 12.3444 - val_acc: 0.4089 - val_loss: 14.1099

# %% [markdown]
# ## 5. Evaluation and Saving

# %%
# Save vocabulary explicitly
with open(config["VOCAB_PATH"], "wb") as f:
    pickle.dump({'config': vectorization.get_config(), 'vocab': vectorization.get_vocabulary()}, f)
print(f"Vocabulary saved to {config['VOCAB_PATH']}")

# Plotting the training curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['acc'], label='Train Accuracy')
plt.plot(history.history['val_acc'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.show()
# Out:
# Vocabulary saved to /kaggle/working/vectorization_layer_state.pkl

# %% [markdown]
# ## 6. Inference / Sanity Check
# Let's test the trained model on a random validation image. The visualization bug has been fixed so the image displays clearly.

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = config["SEQ_LENGTH"] - 1
valid_images = list(valid_data.keys())

def generate_caption(img_path):
    sample_img = decode_and_resize(img_path)
    
    # IMAGE VISUALIZATION
    img_to_show = sample_img.numpy().astype("uint8")
    plt.imshow(img_to_show)
    plt.axis('off')
    plt.show()

    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)
    encoded_img = caption_model.encoder(img, training=False)

    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(tokenized_caption, encoded_img, training=False, mask=mask)
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup.get(sampled_token_index, "<unk>")
        if sampled_token == "<end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "").replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)
    
    return decoded_caption

# Test on a random image
random_test_img = np.random.choice(valid_images)
generate_caption(random_test_img)
# Out:
# Predicted Caption:  4 a man in a white shirt is standing in front of a wall
# '4 a man in a white shirt is standing in front of a wall'

# %% [markdown]
# ## 7. The "Best" Step: TFLite Compression for Edge Devices
# The standard `.keras` model is >200MB because it saves training states (optimizer weights). For real-time execution on a portable device (EchoLens), we compress it into two lightweight `TFLite` files (Encoder and Decoder), shrinking it down to roughly ~45MB total.

# %%
import tensorflow as tf
from keras import layers

print("Isolating sub-models for TFLite conversion...")

# 1. Isolate the Image Encoder
image_input = tf.keras.Input(shape=(299, 299, 3), name="image_input")
cnn_features = caption_model.cnn_model(image_input)
encoded_features = caption_model.encoder(cnn_features, training=False)
encoder_model = tf.keras.Model(inputs=image_input, outputs=encoded_features, name="tflite_encoder")

# 2. Isolate the Text Decoder
seq_input = tf.keras.Input(shape=(None,), dtype=tf.int32, name="sequence_input")
enc_output_input = tf.keras.Input(shape=(None, config["EMBED_DIM"]), dtype=tf.float32, name="encoded_image_input")

# Wrap mask generation in a Lambda layer to handle KerasTensors ---
mask = layers.Lambda(lambda x: tf.math.not_equal(x, 0))(seq_input)

# Pass the mask into the decoder
preds = caption_model.decoder(seq_input, enc_output_input, training=False, mask=mask)
decoder_model = tf.keras.Model(inputs=[seq_input, enc_output_input], outputs=preds, name="tflite_decoder")

# 3. Setup Converter with Dynamic Range Quantization
def convert_and_save(model, filename):
    print(f"Converting {filename}...")
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    # Enable 8-bit dynamic range quantization to shrink model size by ~4x
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.target_spec.supported_ops = [
        tf.lite.OpsSet.TFLITE_BUILTINS, 
        tf.lite.OpsSet.SELECT_TF_OPS
    ]
    tflite_model = converter.convert()
    
    with open(f"/kaggle/working/{filename}", 'wb') as f:
        f.write(tflite_model)
    print(f"Saved /kaggle/working/{filename} (Size: {len(tflite_model) / (1024 * 1024):.2f} MB)")

# 4. Execute Conversion
convert_and_save(encoder_model, "echolens_encoder_quantized.tflite")
convert_and_save(decoder_model, "echolens_decoder_quantized.tflite")
print("TFLite models are ready for download in the Output panel!")
# Out:
# Isolating sub-models for TFLite conversion...
# Converting echolens_encoder_quantized.tflite...
# INFO:tensorflow:Assets written to: /tmp/tmpsyolap0r/assets
# INFO:tensorflow:Assets written to: /tmp/tmpsyolap0r/assets
# Saved artifact at '/tmp/tmpsyolap0r'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='image_input')
# Output Type:
#   TensorSpec(shape=(None, 100, 512), dtype=tf.float32, name=None)
# Captures:
#   132418851270160: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132418851270352: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   132418849931344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849932880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849933648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849934224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849931728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849935376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849935568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849931920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849934608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849934032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849937104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849933456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849937296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849936336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849934800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849936144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849937680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849938640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849936912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849938448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849939216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849936528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849937872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849939600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849939024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849940368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849938064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849939792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849940752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849941328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849939984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849941520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849938832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849940176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849942480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849942096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849943056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849942288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849940560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849942864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849943440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849944016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849943248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849940944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849943824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849944400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849944976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849944208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849945360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849941712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849944784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849945168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849945936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849946128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849945744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849946320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849942672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849945552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828464208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849943632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418849941904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828464400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828465552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828464592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828466512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828466896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828464784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828466320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828466704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828467472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828464976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828465360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828467088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828465168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828467280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828468048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418828467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869265424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869265040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869266192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869266384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869264656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869266768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869265616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869265232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869266576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869264464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869267344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869266000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869268112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869268304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869267728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869266960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869268688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869269264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869267920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869267536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869269072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869269648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869270224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869269456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869270608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869268496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869270032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869270416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869268880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869271184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869269840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869271952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869267152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869271376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869271760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869272336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869272912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869272144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869271568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869272720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869273296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869273872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869273104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869274256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869270992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869273680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869274064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869272528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869274832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869273488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869275600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869274448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869276752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869275408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869275024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869277136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869277712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869275984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869277520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869276368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869278672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869277328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869279440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869279056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869278288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869280592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869279824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869280208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869270800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418869278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872361232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872362576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872362384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872362192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872362000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872361808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872361040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872362960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872363344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872363920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872364496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872363152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872364304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872364880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872365456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872364688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872365840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872361616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872365648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872364112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872366416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872365072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872367376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872366800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872366032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872367760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872368336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872366992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872368144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872368720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872369296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872368528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872367568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872369104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872369488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872367952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872370256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872371024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872366224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872371216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872369872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872371600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872372176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872370640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872372560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872373136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872372368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872373520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872371408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872372944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872371792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872374096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872372752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872374864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872370064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872374288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872374672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872375248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872375824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872375056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872374480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872375632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872376208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872376784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872376016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872362768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872373712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872376400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872376976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872376592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872377168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872373904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418872375440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851259408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851258832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851258640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851260368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851260944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851259600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851259024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851260752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851261328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851261904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851261136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851262288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851260176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851261712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851262096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851260560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851262864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851261520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851263632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851263824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851263248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851262480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851264208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851264784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851263440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851263056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851264592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851265168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851265744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851264976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851266128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851265552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851265936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851264400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851266704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851265360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851267472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851267664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851267088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851266320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851268048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851268624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851267280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851266896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851268432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851269008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851269584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851268816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851269968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851267856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851269392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851269776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851268240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851270544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851269200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851271312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851266512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851270736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851271120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851271696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851272272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851272848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851273424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853123280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853122896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853120976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853120400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853121552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853119632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853120592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853119824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853119056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853118672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853119440: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1779645681.781475      23 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1779645681.783359      23 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1779645682.068890      23 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Saved /kaggle/working/echolens_encoder_quantized.tflite (Size: 6.02 MB)
# Converting echolens_decoder_quantized.tflite...
# INFO:tensorflow:Assets written to: /tmp/tmpz34ya0x3/assets
# INFO:tensorflow:Assets written to: /tmp/tmpz34ya0x3/assets
# Saved artifact at '/tmp/tmpz34ya0x3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, None), dtype=tf.int32, name='sequence_input'), TensorSpec(shape=(None, None, 512), dtype=tf.float32, name='encoded_image_input')]
# Output Type:
#   TensorSpec(shape=(None, None, 10000), dtype=tf.float32, name=None)
# Captures:
#   132418853118480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418851272464: TensorSpec(shape=(), dtype=tf.float32, name=None)
#   132418853120208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853117136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853116752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853117328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853113296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853116368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853117904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853114640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853121744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853115984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853115600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853115024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853113488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853113872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853115408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853117520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853116944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853111184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853115792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853112912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853112720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853113104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853110608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853112336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853110800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132418853112144: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1779645688.078625      23 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1779645688.078653      23 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Saved /kaggle/working/echolens_decoder_quantized.tflite (Size: 14.60 MB)
# TFLite models are ready for download in the Output panel!
