# %% [markdown]
# # EchoLens: Ultimate Image Captioning Pipeline
# This notebook trains the EfficientNetB0 + Transformer Encoder-Decoder model. It features **Dynamic Path Finding** (so it never crashes on Kaggle paths), **Fixed Visualization**, and **TFLite Export** for edge-device compression.

# %% [markdown]
# ## 1. Dynamic Path Finding & Configuration

# %%
import os
import re
import pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# tf.config.run_functions_eagerly(True)
import keras
from keras import layers
from keras.applications import efficientnet
from keras.layers import TextVectorization

os.environ["KERAS_BACKEND"] = "tensorflow"
keras.utils.set_random_seed(111)

# DYNAMIC PATH FINDER
found_images_path = ""
found_captions_file = ""

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if filename.endswith(('.txt', '.csv')) and ('caption' in filename.lower() or 'result' in filename.lower()):
            found_captions_file = os.path.join(dirname, filename)
        if filename.endswith('.jpg') and not found_images_path:
            found_images_path = dirname

print(f"Dynamically Found Images Path: {found_images_path}")
print(f"Dynamically Found Captions File: {found_captions_file}")


# CONFIGURATION

config = {
    "IMAGES_PATH": found_images_path,
    "CAPTIONS_FILE": found_captions_file,
    "IMAGE_SIZE": (299, 299),
    "VOCAB_SIZE": 10000,
    "SEQ_LENGTH": 25,
    "EMBED_DIM": 512,
    "FF_DIM": 512,
    "BATCH_SIZE": 32,
    "EPOCHS": 15,
    "MODEL_PATH": "/kaggle/working/caption_model.keras",
    "VOCAB_PATH": "/kaggle/working/vectorization_layer_state.pkl"
}
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# 2026-05-22 21:55:42.629966: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779486942.825737      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779486942.877273      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779486943.300007      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779486943.300055      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779486943.300058      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779486943.300061      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Dynamically Found Images Path: /kaggle/input/datasets/princelv84/flickr30k/Images
# Dynamically Found Captions File: /kaggle/input/datasets/princelv84/flickr30k/Images/results.csv

# %% [markdown]
# ## 2. Data Loading and Preprocessing

# %%
def load_captions_data(filename):
    with open(filename, encoding="utf8") as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []
        images_to_skip = set()

        # Skip CSV Header if present
        if len(caption_data) > 0 and ("image" in caption_data[0].lower() or "caption" in caption_data[0].lower()):
            caption_data = caption_data[1:]

        for line in caption_data:
            line = line.replace('|', ',').rstrip("\n") # Handle weird delimiters just in case
            parts = line.strip().lower().split(",", 1)
            if len(parts) < 2: continue
            
            img_name, caption = parts
            img_path = os.path.join(config["IMAGES_PATH"], img_name.strip())

            tokens = caption.strip().split()
            if len(tokens) < 5 or len(tokens) > config["SEQ_LENGTH"]:
                images_to_skip.add(img_path)
                continue

            if img_path.endswith("jpg") and img_path not in images_to_skip:
                caption = "<start> " + caption.strip() + " <end>"
                text_data.append(caption)

                if img_path in caption_mapping:
                    caption_mapping[img_path].append(caption)
                else:
                    caption_mapping[img_path] = [caption]

        for img_path in images_to_skip:
            if img_path in caption_mapping:
                del caption_mapping[img_path]

        return caption_mapping, text_data

def train_val_split(caption_data, train_size=0.8, shuffle=True):
    all_images = list(caption_data.keys())
    if shuffle:
        np.random.shuffle(all_images)
    train_size = int(len(caption_data) * train_size)
    return (
        {img_name: caption_data[img_name] for img_name in all_images[:train_size]},
        {img_name: caption_data[img_name] for img_name in all_images[train_size:]}
    )

captions_mapping, text_data = load_captions_data(config["CAPTIONS_FILE"])
train_data, valid_data = train_val_split(captions_mapping)
print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(valid_data)}")
# Out:
# Training samples: 20915
# Validation samples: 5229

# %%
strip_chars = r"!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~".replace("<", "").replace(">", "")
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")

vectorization = TextVectorization(
    max_tokens=config["VOCAB_SIZE"],
    output_mode="int",
    output_sequence_length=config["SEQ_LENGTH"],
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

image_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomContrast(0.3),
])

def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, config["IMAGE_SIZE"])
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img

def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)

# def make_dataset(images, captions):
#     dataset = tf.data.Dataset.from_tensor_slices((images, captions))
#     dataset = dataset.shuffle(config["BATCH_SIZE"] * 8)
#     dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
#     dataset = dataset.batch(config["BATCH_SIZE"]).prefetch(AUTOTUNE)
#     return dataset

def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(config["BATCH_SIZE"] * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    
    # ADD THIS LINE TO CACHE IMAGES IN RAM:
    dataset = dataset.cache() 
    
    dataset = dataset.batch(config["BATCH_SIZE"]).prefetch(AUTOTUNE)
    return dataset

train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))
valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))
# Out:
# I0000 00:00:1779487231.970888      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# ## 3. Model Architecture (EfficientNet + Transformer)

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(input_shape=(*config["IMAGE_SIZE"], 3), include_top=False, weights="imagenet")
    base_model.trainable = False
    base_model_out = layers.Reshape((-1, base_model.output.shape[-1]))(base_model.output)
    return keras.models.Model(base_model.input, base_model_out)

@keras.utils.register_keras_serializable()
class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=0.0)
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)
        attention_output_1 = self.attention_1(query=inputs, value=inputs, key=inputs, training=training)
        return self.layernorm_2(inputs + attention_output_1)

@keras.utils.register_keras_serializable()
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.position_embeddings = layers.Embedding(input_dim=sequence_length, output_dim=embed_dim)
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs) * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

@keras.utils.register_keras_serializable()
class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=0.1)
        self.attention_2 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=0.1)
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.embedding = PositionalEmbedding(embed_dim=config["EMBED_DIM"], sequence_length=config["SEQ_LENGTH"], vocab_size=config["VOCAB_SIZE"])
        self.out = layers.Dense(config["VOCAB_SIZE"], activation="softmax")
        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)
        attention_output_1 = self.attention_1(query=inputs, value=inputs, key=inputs, attention_mask=combined_mask, training=training)
        out_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(query=out_1, value=encoder_outputs, key=encoder_outputs, attention_mask=padding_mask, training=training)
        out_2 = self.layernorm_2(out_1 + attention_output_2)
        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)
        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        return self.out(ffn_out)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat([tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

@keras.utils.register_keras_serializable()
class ImageCaptioningModel(keras.Model):
    def __init__(self, cnn_model, encoder, decoder, num_captions_per_image=5, image_aug=None, **kwargs):
        super().__init__(**kwargs)
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(batch_seq_inp, encoder_out, training=training, mask=mask)
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0
        if self.image_aug:
            batch_img = self.image_aug(batch_img)
        img_embed = self.cnn_model(batch_img)

        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(img_embed, batch_seq[:, i, :], training=True)
                batch_loss += loss
                batch_acc += acc
            train_vars = self.encoder.trainable_variables + self.decoder.trainable_variables
            grads = tape.gradient(loss, train_vars)
            self.optimizer.apply_gradients(zip(grads, train_vars))

        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0
        img_embed = self.cnn_model(batch_img)

        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(img_embed, batch_seq[:, i, :], training=False)
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    @property
    def metrics(self):
        return [self.loss_tracker, self.acc_tracker]

    def get_config(self):
        conf = super().get_config()
        conf.update({
            "cnn_model": keras.saving.serialize_keras_object(self.cnn_model),
            "encoder": keras.saving.serialize_keras_object(self.encoder),
            "decoder": keras.saving.serialize_keras_object(self.decoder),
            "num_captions_per_image": self.num_captions_per_image,
            "image_aug": keras.saving.serialize_keras_object(self.image_aug),
        })
        return conf

    @classmethod
    def from_config(cls, conf):
        cnn_model = keras.saving.deserialize_keras_object(conf.pop("cnn_model"))
        encoder = keras.saving.deserialize_keras_object(conf.pop("encoder"))
        decoder = keras.saving.deserialize_keras_object(conf.pop("decoder"))
        image_aug = keras.saving.deserialize_keras_object(conf.pop("image_aug"))
        num_captions_per_image = conf.pop("num_captions_per_image")
        return cls(cnn_model=cnn_model, encoder=encoder, decoder=decoder, num_captions_per_image=num_captions_per_image, image_aug=image_aug, **conf)

    def build(self, input_shape, seq_len=25):
        dummy_images = tf.zeros(input_shape)
        if self.image_aug:
            dummy_images = self.image_aug(dummy_images)
        img_embed = self.cnn_model(dummy_images)
        encoder_out = self.encoder(img_embed, training=False)
        dummy_caption = tf.zeros((input_shape[0], seq_len), dtype=tf.int32)
        dummy_mask = tf.ones_like(dummy_caption, dtype=tf.bool)
        _ = self.decoder(dummy_caption, encoder_out, training=False, mask=dummy_mask)
        super().build(input_shape)

# %% [markdown]
# ## 4. Training & Callbacks

# %%
@keras.utils.register_keras_serializable()
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(global_step < warmup_steps, lambda: warmup_learning_rate, lambda: self.post_warmup_learning_rate)

    def get_config(self):
        return {"post_warmup_learning_rate": float(self.post_warmup_learning_rate), "warmup_steps": int(self.warmup_steps)}

    @classmethod
    def from_config(cls, conf):
        return cls(**conf)

cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=config["EMBED_DIM"], dense_dim=config["FF_DIM"], num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=config["EMBED_DIM"], ff_dim=config["FF_DIM"], num_heads=2)
caption_model = ImageCaptioningModel(cnn_model=cnn_model, encoder=encoder, decoder=decoder, image_aug=image_augmentation)

cross_entropy = keras.losses.SparseCategoricalCrossentropy(from_logits=False, reduction=None)

num_train_steps = len(train_dataset) * config["EPOCHS"]
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)
caption_model.build(input_shape=(4, *config["IMAGE_SIZE"], 3))

# Callbacks to save best model and stop if it stops improving
callbacks = [
    keras.callbacks.ModelCheckpoint(config["MODEL_PATH"], save_best_only=True, save_weights_only=False, monitor="val_loss"),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)
]

print("Starting Training...")
history = caption_model.fit(
    train_dataset, 
    epochs=config["EPOCHS"], 
    validation_data=valid_dataset,
    callbacks=callbacks
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# I0000 00:00:1779487239.118689      23 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Starting Training...
# Epoch 1/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 298s 404ms/step - acc: 0.2159 - loss: 27.1991 - val_acc: 0.3555 - val_loss: 16.7876
# Epoch 2/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 394ms/step - acc: 0.3487 - loss: 16.8666 - val_acc: 0.3798 - val_loss: 15.4080
# Epoch 3/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 258s 394ms/step - acc: 0.3701 - loss: 15.5830 - val_acc: 0.3909 - val_loss: 14.8218
# Epoch 4/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 258s 394ms/step - acc: 0.3827 - loss: 14.8590 - val_acc: 0.3977 - val_loss: 14.5025
# Epoch 5/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 258s 394ms/step - acc: 0.3921 - loss: 14.3545 - val_acc: 0.4017 - val_loss: 14.2887
# Epoch 6/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 258s 395ms/step - acc: 0.4001 - loss: 13.9686 - val_acc: 0.4051 - val_loss: 14.1911
# Epoch 7/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 258s 394ms/step - acc: 0.4063 - loss: 13.6313 - val_acc: 0.4064 - val_loss: 14.0967
# Epoch 8/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 257s 394ms/step - acc: 0.4121 - loss: 13.3571 - val_acc: 0.4085 - val_loss: 14.0571
# Epoch 9/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 258s 394ms/step - acc: 0.4178 - loss: 13.1088 - val_acc: 0.4080 - val_loss: 14.0486
# Epoch 10/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 262s 400ms/step - acc: 0.4223 - loss: 12.8932 - val_acc: 0.4089 - val_loss: 14.0408
# Epoch 11/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 256s 391ms/step - acc: 0.4271 - loss: 12.6936 - val_acc: 0.4089 - val_loss: 14.0807
# Epoch 12/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 256s 392ms/step - acc: 0.4310 - loss: 12.5060 - val_acc: 0.4089 - val_loss: 14.0854
# Epoch 13/15
# 654/654 ━━━━━━━━━━━━━━━━━━━━ 256s 391ms/step - acc: 0.4352 - loss: 12.3461 - val_acc: 0.4090 - val_loss: 14.1059

# %% [markdown]
# ## 5. Evaluation and Saving

# %%
# Save vocabulary explicitly
with open(config["VOCAB_PATH"], "wb") as f:
    pickle.dump({'config': vectorization.get_config(), 'vocab': vectorization.get_vocabulary()}, f)
print(f"Vocabulary saved to {config['VOCAB_PATH']}")

# Plotting the training curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['acc'], label='Train Accuracy')
plt.plot(history.history['val_acc'], label='Val Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.show()
# Out:
# Vocabulary saved to /kaggle/working/vectorization_layer_state.pkl

# %% [markdown]
# ## 6. Inference / Sanity Check
# Let's test the trained model on a random validation image. The visualization bug has been fixed so the image displays clearly.

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = config["SEQ_LENGTH"] - 1
valid_images = list(valid_data.keys())

def generate_caption(img_path):
    sample_img = decode_and_resize(img_path)
    
    # IMAGE VISUALIZATION
    img_to_show = sample_img.numpy().astype("uint8")
    plt.imshow(img_to_show)
    plt.axis('off')
    plt.show()

    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)
    encoded_img = caption_model.encoder(img, training=False)

    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(tokenized_caption, encoded_img, training=False, mask=mask)
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup.get(sampled_token_index, "<unk>")
        if sampled_token == "<end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "").replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)
    
    return decoded_caption

# Test on a random image
random_test_img = np.random.choice(valid_images)
generate_caption(random_test_img)
# Out:
# Predicted Caption:  4 a man in a suit is standing in front of a large wall
# '4 a man in a suit is standing in front of a large wall'

# %% [markdown]
# ## 7. The "Best" Step: TFLite Compression for Edge Devices
# The standard `.keras` model is >200MB because it saves training states (optimizer weights). For real-time execution on a portable device (EchoLens), we compress it into two lightweight `TFLite` files (Encoder and Decoder), shrinking it down to roughly ~45MB total.

# %%
import tensorflow as tf
from keras import layers

print("Isolating sub-models for TFLite conversion...")

# 1. Isolate the Image Encoder
image_input = tf.keras.Input(shape=(299, 299, 3), name="image_input")
cnn_features = caption_model.cnn_model(image_input)
encoded_features = caption_model.encoder(cnn_features, training=False)
encoder_model = tf.keras.Model(inputs=image_input, outputs=encoded_features, name="tflite_encoder")

# 2. Isolate the Text Decoder
seq_input = tf.keras.Input(shape=(None,), dtype=tf.int32, name="sequence_input")
enc_output_input = tf.keras.Input(shape=(None, config["EMBED_DIM"]), dtype=tf.float32, name="encoded_image_input")

# Wrap mask generation in a Lambda layer to handle KerasTensors ---
mask = layers.Lambda(lambda x: tf.math.not_equal(x, 0))(seq_input)

# Pass the mask into the decoder
preds = caption_model.decoder(seq_input, enc_output_input, training=False, mask=mask)
decoder_model = tf.keras.Model(inputs=[seq_input, enc_output_input], outputs=preds, name="tflite_decoder")

# 3. Setup Converter with Dynamic Range Quantization
def convert_and_save(model, filename):
    print(f"Converting {filename}...")
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    # Enable 8-bit dynamic range quantization to shrink model size by ~4x
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.target_spec.supported_ops = [
        tf.lite.OpsSet.TFLITE_BUILTINS, 
        tf.lite.OpsSet.SELECT_TF_OPS
    ]
    tflite_model = converter.convert()
    
    with open(f"/kaggle/working/{filename}", 'wb') as f:
        f.write(tflite_model)
    print(f"Saved /kaggle/working/{filename} (Size: {len(tflite_model) / (1024 * 1024):.2f} MB)")

# 4. Execute Conversion
convert_and_save(encoder_model, "echolens_encoder_quantized.tflite")
convert_and_save(decoder_model, "echolens_decoder_quantized.tflite")
print("TFLite models are ready for download in the Output panel!")
# Out:
# Isolating sub-models for TFLite conversion...
# Converting echolens_encoder_quantized.tflite...
# INFO:tensorflow:Assets written to: /tmp/tmpw7l9eg67/assets
# INFO:tensorflow:Assets written to: /tmp/tmpw7l9eg67/assets
# Saved artifact at '/tmp/tmpw7l9eg67'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='image_input')
# Output Type:
#   TensorSpec(shape=(None, 100, 512), dtype=tf.float32, name=None)
# Captures:
#   134994976206160: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   134994976206352: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   134994953914320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953913552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953912784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953914512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953915088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953912400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953916240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953916432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953912592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953915472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953914896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953917968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953914128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953918160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953917200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953915664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953917008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953918544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953919504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953917776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953919312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953920080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953917392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953918736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953920464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953919888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953921232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953918928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953920656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953921616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953922192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953920848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953922384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953919696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953921040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953923344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953922960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953923920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953921424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953923728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953924304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953924880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953924112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953921808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953925840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953926224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953922576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953925648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953926800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953926608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953923536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932445072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953924496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953922768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932445264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932446416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932445456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932446800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932447376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932446608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932447760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932445648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932447184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932447568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932446032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932448336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932446992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932449104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932445840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932448144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932446224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932447952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932448720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932448912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953847632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994932448528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953848592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953847056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953848976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953847824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953847440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953848208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953850512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953850896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953851472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953850128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953851280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953851856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953852432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953851664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953852624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953851088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953853392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953852048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953854160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953849360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953853584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953853968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953854544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953855120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953854352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953853776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953854928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953855504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953856080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953855312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953856464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953853200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953855888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953856272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953854736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953857040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953855696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953857808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953858000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953857424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953856656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953858384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953858960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953857616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953857232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953858768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953859344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953859920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953859152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953860304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953858192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953859728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953860112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953858576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953860880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953859536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953861648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953861840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953861264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953860496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953862224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953862800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953861456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953862032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953862416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953861072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953862992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953862608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953860688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994953853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930075408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930075024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930074832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930073680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930074256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930075984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930074640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930074448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930075792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930076368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930076944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930076176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930075600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930076752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930077328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930077904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930077136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930078288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930074064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930077712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930078096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930076560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930078864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930077520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930079632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930079824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930079248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930078480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930080208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930080784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930079440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930079056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930080592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930081168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930081744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930080976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930082128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930080016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930081552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930081936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930080400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930082704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930081360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930083472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930083088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930083280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930075216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930084240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930084816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930082320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930078672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930082512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994979547536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994979538320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930084624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930085968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930085392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930085008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930085584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930085200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930086544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930084048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930087312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930083856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930086736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930087120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930087696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930088272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930087504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930086928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930088080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930088656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930089232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930088464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930085776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930086160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930089040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930087888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930089808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930088848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930086352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994930089424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976195792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976195216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976194832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976196368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976196944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976195024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976195600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976196752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976197328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976197904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976197136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976198288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976196176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976197712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976198096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976196560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976198864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976197520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976199632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976199824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976199248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976198480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976200208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976200784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976199440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976199056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976200592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976201168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976201744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976200976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976202128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976200016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976201552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976201936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976200400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976202704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976201360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976203472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976203664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976203088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976202320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976204048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976204624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976203280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976202896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976204432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976205008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976205584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976204816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976205968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976203856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976205392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976205776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976204240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976206544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976205200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976207312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976202512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976207120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976207696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976208272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976207888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963458832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963460944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963461520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963457488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963459216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963458448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963459408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963458256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963457296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963455952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963454800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963457680: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1779490650.081332      23 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1779490650.083714      23 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1779490650.362045      23 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Saved /kaggle/working/echolens_encoder_quantized.tflite (Size: 6.02 MB)
# Converting echolens_decoder_quantized.tflite...
# INFO:tensorflow:Assets written to: /tmp/tmptj8ms31w/assets
# INFO:tensorflow:Assets written to: /tmp/tmptj8ms31w/assets
# Saved artifact at '/tmp/tmptj8ms31w'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, None), dtype=tf.int32, name='sequence_input'), TensorSpec(shape=(None, None, 512), dtype=tf.float32, name='encoded_image_input')]
# Output Type:
#   TensorSpec(shape=(None, None, 10000), dtype=tf.float32, name=None)
# Captures:
#   134994963455760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994976208464: TensorSpec(shape=(), dtype=tf.float32, name=None)
#   134994963457872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963455184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963454608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963455376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963454992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963454032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963456144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963455568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963454416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963453456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963459600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963453840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963452880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963452688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963452496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963454224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963456336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963453072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963450576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963451920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963451152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963449424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963449232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963450960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963450768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963451344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963450000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134994963448848: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved /kaggle/working/echolens_decoder_quantized.tflite (Size: 14.60 MB)
# TFLite models are ready for download in the Output panel!
# W0000 00:00:1779490656.331943      23 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1779490656.331972      23 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
